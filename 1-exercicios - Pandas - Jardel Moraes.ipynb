# %% [markdown]
# ### 1. Ler e exibir um arquivo CSV usando pandas

# %%
import pandas as pd

df = spark.read.csv("/FileStore/tables/Heart_disease_cleveland_new.csv", header=True, sep=',')
df = df.toPandas()

df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>cp</th>
#       <th>trestbps</th>
#       <th>chol</th>
#       <th>fbs</th>
#       <th>restecg</th>
#       <th>thalach</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>ca</th>
#       <th>thal</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63</td>
#       <td>1</td>
#       <td>0</td>
#       <td>145</td>
#       <td>233</td>
#       <td>1</td>
#       <td>2</td>
#       <td>150</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>67</td>
#       <td>1</td>
#       <td>3</td>
#       <td>160</td>
#       <td>286</td>
#       <td>0</td>
#       <td>2</td>
#       <td>108</td>
#       <td>1</td>
#       <td>1.5</td>
#       <td>1</td>
#       <td>3</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>67</td>
#       <td>1</td>
#       <td>3</td>
#       <td>120</td>
#       <td>229</td>
#       <td>0</td>
#       <td>2</td>
#       <td>129</td>
#       <td>1</td>
#       <td>2.6</td>
#       <td>1</td>
#       <td>2</td>
#       <td>3</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>37</td>
#       <td>1</td>
#       <td>2</td>
#       <td>130</td>
#       <td>250</td>
#       <td>0</td>
#       <td>0</td>
#       <td>187</td>
#       <td>0</td>
#       <td>3.5</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>41</td>
#       <td>0</td>
#       <td>1</td>
#       <td>130</td>
#       <td>204</td>
#       <td>0</td>
#       <td>2</td>
#       <td>172</td>
#       <td>0</td>
#       <td>1.4</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 2. Selecionar colunas específicas de um DataFrame usando pandas

# %%
df[['age','sex']]
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>67</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>67</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>37</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>41</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>45</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>68</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td>57</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>57</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td>38</td>
#       <td>1</td>
#     </tr>
#   </tbody>
# </table>
# <p>303 rows × 2 columns</p>
# </div>

# %% [markdown]
# ### 3. Filtrar linhas com base em uma condição usando pandas

# %%
df.filter(like='e')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>age</th>
#       <th>sex</th>
#       <th>trestbps</th>
#       <th>restecg</th>
#       <th>exang</th>
#       <th>oldpeak</th>
#       <th>slope</th>
#       <th>target</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63</td>
#       <td>1</td>
#       <td>145</td>
#       <td>2</td>
#       <td>0</td>
#       <td>2.3</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>67</td>
#       <td>1</td>
#       <td>160</td>
#       <td>2</td>
#       <td>1</td>
#       <td>1.5</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>67</td>
#       <td>1</td>
#       <td>120</td>
#       <td>2</td>
#       <td>1</td>
#       <td>2.6</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>37</td>
#       <td>1</td>
#       <td>130</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3.5</td>
#       <td>2</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>41</td>
#       <td>0</td>
#       <td>130</td>
#       <td>2</td>
#       <td>0</td>
#       <td>1.4</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>298</th>
#       <td>45</td>
#       <td>1</td>
#       <td>110</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1.2</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>299</th>
#       <td>68</td>
#       <td>1</td>
#       <td>144</td>
#       <td>0</td>
#       <td>0</td>
#       <td>3.4</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>300</th>
#       <td>57</td>
#       <td>1</td>
#       <td>130</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1.2</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>301</th>
#       <td>57</td>
#       <td>0</td>
#       <td>130</td>
#       <td>2</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>302</th>
#       <td>38</td>
#       <td>1</td>
#       <td>138</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# <p>303 rows × 8 columns</p>
# </div>

# %% [markdown]
# ### 4. Agrupar dados com base em uma coluna usando pandas

# %%
df.groupby('sex').agg(n=('sex', 'count')).reset_index().sort_values('n', ascending=False)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>sex</th>
#       <th>n</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>1</th>
#       <td>1</td>
#       <td>206</td>
#     </tr>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>97</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### 5. Usar a função max em alguma coluna do DataFrame

# %%
df['age'].max()
# Out:
# Out[51]: '77'
